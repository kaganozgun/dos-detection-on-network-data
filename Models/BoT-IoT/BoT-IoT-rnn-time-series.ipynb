# %%
import pandas as pd
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
base_path = "/content/drive/MyDrive/Okul/İTÜ/Bilgisayar Mühendisliği Yüksek Lisans/Yüksek Lisans/YL Tez/Development/Bot-Iot"
X_train = np.genfromtxt(f"{base_path}/Sampled/30-sampled-x-train.csv", delimiter=',')
y_train = np.genfromtxt(f"{base_path}/Sampled/30-sampled-y-train.csv", delimiter=',')
X_test = np.genfromtxt(f"{base_path}/Sampled/30-sampled-x-test.csv", delimiter=',')
y_test = np.genfromtxt(f"{base_path}/Sampled/30-sampled-y-test.csv", delimiter=',')

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
y_train = y_train.astype("int64")
y_test = y_test.astype("int64")

num_classes = len(np.unique(y_train))

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=X_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 100
batch_size = 10

callbacks = [
    keras.callbacks.ModelCheckpoint(
        f"{base_path}/Model/rnn-time-series-best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    X_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/100
# 635/635 [==============================] - 10s 12ms/step - loss: 0.1483 - sparse_categorical_accuracy: 0.9570 - val_loss: 0.0720 - val_sparse_categorical_accuracy: 0.9880 - lr: 0.0010
# Epoch 2/100
# 635/635 [==============================] - 5s 9ms/step - loss: 0.0523 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.0359 - val_sparse_categorical_accuracy: 0.9855 - lr: 0.0010
# Epoch 3/100
# 635/635 [==============================] - 5s 7ms/step - loss: 0.0415 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.0217 - val_sparse_categorical_accuracy: 0.9943 - lr: 0.0010
# Epoch 4/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0330 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9937 - lr: 0.0010
# Epoch 5/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0274 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.0360 - val_sparse_categorical_accuracy: 0.9912 - lr: 0.0010
# Epoch 6/100
# 635/635 [==============================] - 4s 7ms/step - loss: 0.0304 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.0295 - val_sparse_categorical_accuracy: 0.9912 - lr: 0.0010
# Epoch 7/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0258 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0209 - val_sparse_categorical_accuracy: 0.9950 - lr: 0.0010
# Epoch 8/100
# 635/635 [==============================] - 5s 7ms/step - loss: 0.0269 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.0265 - val_sparse_categorical_accuracy: 0.9950 - lr: 0.0010
# Epoch 9/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0246 - sparse_categorical_accuracy: 0.9924 - val_loss: 0.0200 - val_sparse_categorical_accuracy: 0.9956 - lr: 0.0010
# Epoch 10/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9956 - lr: 0.0010
# Epoch 11/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0252 - sparse_categorical_accuracy: 0.9924 - val_loss: 0.0281 - val_sparse_categorical_accuracy: 0.9937 - lr: 0.0010
# Epoch 12/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0184 - val_sparse_categorical_accuracy: 0.9956 - lr: 0.0010
# Epoch 13/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0198 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 0.9950 - lr: 0.0010
# Epoch 14/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0184 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 0.9950 - lr: 0.0010
# Epoch 15/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0186 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 0.9937 - lr: 0.0010
# Epoch 16/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0202 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.1893 - val_sparse_categorical_accuracy: 0.9175 - lr: 0.0010
# Epoch 17/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0182 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0151 - val_sparse_categorical_accuracy: 0.9956 - lr: 0.0010
# Epoch 18/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0181 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.0189 - val_sparse_categorical_accuracy: 0.9943 - lr: 0.0010
# Epoch 19/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.0213 - val_sparse_categorical_accuracy: 0.9937 - lr: 0.0010
# Epoch 20/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0188 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0191 - val_sparse_categorical_accuracy: 0.9937 - lr: 0.0010
# Epoch 21/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0153 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0203 - val_sparse_categorical_accuracy: 0.9943 - lr: 0.0010
# Epoch 22/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0165 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.0182 - val_sparse_categorical_accuracy: 0.9950 - lr: 0.0010
# Epoch 23/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0156 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0181 - val_sparse_categorical_accuracy: 0.9943 - lr: 0.0010
# Epoch 24/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0133 - sparse_categorical_accuracy: 0.9965 - val_loss: 0.0171 - val_sparse_categorical_accuracy: 0.9943 - lr: 0.0010
# Epoch 25/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0535 - val_sparse_categorical_accuracy: 0.9861 - lr: 0.0010
# Epoch 26/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0168 - sparse_categorical_accuracy: 0.9942 - val_loss: 0.0188 - val_sparse_categorical_accuracy: 0.9950 - lr: 0.0010
# Epoch 27/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0193 - val_sparse_categorical_accuracy: 0.9943 - lr: 0.0010
# Epoch 28/100
# 635/635 [==============================] - 5s 9ms/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.0162 - val_sparse_categorical_accuracy: 0.9950 - lr: 0.0010
# Epoch 29/100
# 635/635 [==============================] - 6s 10ms/step - loss: 0.0119 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0160 - val_sparse_categorical_accuracy: 0.9956 - lr: 0.0010
# Epoch 30/100
# 635/635 [==============================] - 9s 14ms/step - loss: 0.0138 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0227 - val_sparse_categorical_accuracy: 0.9968 - lr: 0.0010
# Epoch 31/100
# 635/635 [==============================] - 5s 7ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0186 - val_sparse_categorical_accuracy: 0.9950 - lr: 0.0010
# Epoch 32/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0154 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0169 - val_sparse_categorical_accuracy: 0.9937 - lr: 0.0010
# Epoch 33/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9957 - val_loss: 0.0187 - val_sparse_categorical_accuracy: 0.9956 - lr: 0.0010
# Epoch 34/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9968 - val_loss: 0.0279 - val_sparse_categorical_accuracy: 0.9924 - lr: 0.0010
# Epoch 35/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 0.9943 - lr: 0.0010
# Epoch 36/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0251 - val_sparse_categorical_accuracy: 0.9905 - lr: 0.0010
# Epoch 37/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9943 - lr: 0.0010
# Epoch 38/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0102 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0163 - val_sparse_categorical_accuracy: 0.9950 - lr: 5.0000e-04
# Epoch 39/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0096 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0207 - val_sparse_categorical_accuracy: 0.9943 - lr: 5.0000e-04
# Epoch 40/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0097 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0170 - val_sparse_categorical_accuracy: 0.9956 - lr: 5.0000e-04
# Epoch 41/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0100 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 0.9943 - lr: 5.0000e-04
# Epoch 42/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0172 - val_sparse_categorical_accuracy: 0.9956 - lr: 5.0000e-04
# Epoch 43/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9943 - lr: 5.0000e-04
# Epoch 44/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0093 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0190 - val_sparse_categorical_accuracy: 0.9950 - lr: 5.0000e-04
# Epoch 45/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0180 - val_sparse_categorical_accuracy: 0.9950 - lr: 5.0000e-04
# Epoch 46/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0204 - val_sparse_categorical_accuracy: 0.9943 - lr: 5.0000e-04
# Epoch 47/100
# 635/635 [==============================] - 5s 9ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0190 - val_sparse_categorical_accuracy: 0.9943 - lr: 5.0000e-04
# Epoch 48/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0167 - val_sparse_categorical_accuracy: 0.9950 - lr: 5.0000e-04
# Epoch 49/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0085 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0201 - val_sparse_categorical_accuracy: 0.9950 - lr: 5.0000e-04
# Epoch 50/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0092 - sparse_categorical_accuracy: 0.9967 - val_loss: 0.0186 - val_sparse_categorical_accuracy: 0.9950 - lr: 5.0000e-04
# Epoch 51/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0178 - val_sparse_categorical_accuracy: 0.9950 - lr: 5.0000e-04
# Epoch 52/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0081 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0206 - val_sparse_categorical_accuracy: 0.9905 - lr: 5.0000e-04
# Epoch 53/100
# 635/635 [==============================] - 5s 9ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0222 - val_sparse_categorical_accuracy: 0.9924 - lr: 5.0000e-04
# Epoch 54/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0087 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0168 - val_sparse_categorical_accuracy: 0.9956 - lr: 5.0000e-04
# Epoch 55/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0083 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0206 - val_sparse_categorical_accuracy: 0.9931 - lr: 5.0000e-04
# Epoch 56/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0188 - val_sparse_categorical_accuracy: 0.9950 - lr: 5.0000e-04
# Epoch 57/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 0.9950 - lr: 5.0000e-04
# Epoch 58/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0222 - val_sparse_categorical_accuracy: 0.9931 - lr: 2.5000e-04
# Epoch 59/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0072 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0174 - val_sparse_categorical_accuracy: 0.9950 - lr: 2.5000e-04
# Epoch 60/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0068 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0183 - val_sparse_categorical_accuracy: 0.9950 - lr: 2.5000e-04
# Epoch 61/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.0173 - val_sparse_categorical_accuracy: 0.9950 - lr: 2.5000e-04
# Epoch 62/100
# 635/635 [==============================] - 5s 9ms/step - loss: 0.0059 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0181 - val_sparse_categorical_accuracy: 0.9950 - lr: 2.5000e-04
# Epoch 63/100
# 635/635 [==============================] - 5s 7ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0187 - val_sparse_categorical_accuracy: 0.9943 - lr: 2.5000e-04
# Epoch 64/100
# 635/635 [==============================] - 6s 10ms/step - loss: 0.0060 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0187 - val_sparse_categorical_accuracy: 0.9950 - lr: 2.5000e-04
# Epoch 65/100
# 635/635 [==============================] - 6s 9ms/step - loss: 0.0075 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9937 - lr: 2.5000e-04
# Epoch 66/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0073 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0193 - val_sparse_categorical_accuracy: 0.9950 - lr: 2.5000e-04
# Epoch 67/100
# 635/635 [==============================] - 5s 8ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0209 - val_sparse_categorical_accuracy: 0.9937 - lr: 2.5000e-04
# Epoch 67: early stopping

# %%
model = keras.models.load_model(f"{base_path}/Model/rnn-time-series-best_model.h5")

test_loss, test_acc = model.evaluate(X_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 123/123 [==============================] - 1s 6ms/step - loss: 0.0147 - sparse_categorical_accuracy: 0.9972
# Test accuracy 0.9971845149993896
# Test loss 0.014729870483279228

# %%
y_pred_list = np.argmax(model.predict(X_test), axis=-1)
# Out:
# 123/123 [==============================] - 1s 4ms/step

# %%
print(confusion_matrix(y_test, y_pred_list))
print(classification_report(y_test, y_pred_list))
# Out:
# [[2722    6]
#  [   5 1174]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2728
#            1       0.99      1.00      1.00      1179
#
#     accuracy                           1.00      3907
#    macro avg       1.00      1.00      1.00      3907
# weighted avg       1.00      1.00      1.00      3907

# %%
np.savetxt(f"{base_path}/Model/rnn-time-series-y-pred.csv", y_pred_list, delimiter=",")
